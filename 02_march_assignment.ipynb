# %% [markdown]
# Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of
# Matplotlib.

# %% [markdown]
# it is library of visualization in python,which is used for data visualization by the help of graph.
#
# five plots name are given below.
# scattering
# pie chart
# bar chart
# line chart
# plote simple(compre x,y axis)

# %% [markdown]
# Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
# plot a scatter plot.
# import numpy as np
# np.random.seed(3)
# x = 3 + np.random.normal(0, 2, 50)
# y = 3 + np.random.normal(0, 2, len(x))
# Note: Also add title, xlabel, and ylabel to the plot.

# %% [markdown]
# Scatter plot is type of graph which is compare x and y axis by the points it can be bigger or change their colour according to our use.

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.random.randn(40)
y=np.random.randn(40)

# %%
x
# Out:
# array([ 0.87428572, -1.29353663, -0.07974094,  0.56448552,  1.23347104,
#         0.14898639, -0.53058214, -0.73052664,  0.64506198,  0.31306037,
#        -0.51664792, -0.18907167, -0.41619802,  0.72465766, -0.68996068,
#         0.48641448,  0.85151895,  0.48624933, -0.83423985,  1.34499246,
#        -0.67821268,  0.42643507, -0.75333479, -1.74411025,  0.22575027,
#         0.28703516, -0.07744096,  0.2760685 , -0.64841089, -0.73746484,
#        -0.1680901 ,  1.90927681,  0.81481454, -0.51999175,  0.5587132 ,
#        -0.47836466, -0.45726079,  0.85928401, -0.52526465, -1.67563463])

# %%
y
# Out:
# array([-0.05394785,  1.31516722, -0.23733748,  0.88533968,  0.35081584,
#         1.6265736 , -1.41987131,  0.76572107,  0.12224975, -1.15738338,
#         1.06542018, -0.87237566,  1.61923848,  0.51309301,  0.69548398,
#         0.08045739,  0.90452849, -1.86565117,  0.07472779, -0.62825081,
#         0.28266031, -0.04715691,  0.61657788, -0.83763145,  1.83915189,
#         2.3158586 , -0.20828342, -0.01497319,  0.28755765,  1.26408575,
#         1.89690096, -1.20580279, -0.61510856, -1.06215612, -1.11278115,
#        -1.63929625,  0.36280349, -1.15903647,  1.50326195,  0.90831872])

# %%
plt.grid()
plt.scatter(x,y)
plt.figure(figsize=(4,2))

# %%
plt.scatter(x,y)
plt.xlabel("this 'x' axis")
plt.ylabel("this 'y' axis")
plt.title("____x vs y____")
plt.figure(figsize=(4,2))

# %% [markdown]
# Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.
#  Use the following data:
#
# import numpy as np
#
# For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and  y = np.array([0, 100, 200, 300, 400, 500])
#
# For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
#
# For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
#
# For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])

# %%
#this for line1
x1=np.array([0, 1, 2, 3, 4, 5])
y1=np.array([0, 100, 200, 300, 400, 500])

#this for line2
x2=np.array([0, 1, 2, 3, 4, 5])
y2=np.array([50, 20, 40, 20, 60, 70])

#this is for line3
x3=np.array([0, 1, 2, 3, 4, 5])
y3=np.array([10, 20, 30, 40, 50, 60])

#this is for line4
x4=np.array([0, 1, 2, 3, 4, 5])
y4=np.array([200, 350, 250, 550, 450, 150])


fig, axs = plt.subplots(2, 2, figsize=(10, 8))
# Plot line 1
axs[0, 0].plot(x1, y1)
axs[0, 0].set_title('Line 1')

# Plot line 2
axs[1, 0].plot(x2, y2)
axs[1, 0].set_title('Line 2')

# Plot line 3
axs[0, 1].plot(x3, y3)
axs[0, 1].set_title('Line 3')

# Plot line 4
axs[1, 1].plot(x4, y4)
axs[1, 1].set_title('Line 4')

# Adjust spacing between subplots
plt.tight_layout()

# Show the figure
plt.show()

# %% [markdown]
# Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.
# import numpy as np
#
# company = np.array(["Apple", "Microsoft", "Google", "AMD"])
#  profit = np.array([3000, 8000, 1000, 10000])

# %% [markdown]
# bar plot:-It is representation of the data set which is form of the rectagular shape and it is visualization of matplotlib in python.
# It is used for visualise the data and their ratio of assests.

# %%
company=np.array(["Apple","Microsoft","Googl","AMD"])
profit=np.array([3000,8000,1000,10000])

# %%
plt.figure(figsize=(5,3))
plt.barh(company,profit)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# Q5: What is a box plot? Why is it used? Using the following data plot a box plot.
#  box1 = np.random.normal(100, 10, 200)
#
# box2 = np.random.normal(90, 20, 200)+

# %% [markdown]
# Box plot:-it is a type of data representation of plot, it is take the data set in a box and show the their desire value as we set in it( lower  middle larger) assest of any organization, it is use to compare the number like we have to set of data and we have to compare which one give me more income then we use it, it use to veiw the data in same box looses and benifit.

# %%
box1=np.random.normal(100,10,200)
box2=np.random.normal(90,20,200)

# %%
plt.grid()
plt.scatter(box1,box2,c='#ff9999')
plt.figure(figsize=(5,3))
